# %%
import json

results_order1_round1 = json.load(open("/root/projects/O-LoRA/logs_and_outputs/order_1/outputs1/4-agnews/predict_results.json"))
results_order1_round2 = json.load(open("/root/projects/O-LoRA/logs_and_outputs/order_1/outputs2/4-agnews/predict_results.json"))
results_order1_round3 = json.load(open("/root/projects/O-LoRA/logs_and_outputs/order_1/outputs3/4-agnews/predict_results.json"))

acc_1 = results_order1_round1["predict_exact_match"]
acc_2 = results_order1_round2["predict_exact_match"]
acc_3 = results_order1_round3["predict_exact_match"]

print(acc_1, acc_2, acc_3), print((acc_1+acc_2+acc_3)/3)
# Out:
# 75.9934 73.0066 78.0658
# 75.6886
# (None, None)
